# %%
# %run ../../import_src.py

import lymedata
from lymedata import *
import constants
from constants import *

import display_stats
from display_stats import *

# %%
# OWD
# Days Statistics (all Add'l Circumstnaces)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_OWD, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='OWD: Neuro vs Non-Neuro', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1562
# Only Neuro: 632
# Only Mus: 963
# Neither Neuro nor Mus: 806
# Dropping 99
# (1619, 9)
# Index(['Physical Health Days', 'Mental Health Days', 'Bed Days', 'Bio Sex',
#        'Disability', 'musculo', 'neither', 'both', 'neuro'],
#       dtype='object')
# musculo group: 450
# neither group: 232
# both group: 655
# neuro group: 282

# %%
# CNS1
# Days Statistics (all Add'l Circumstnaces)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_CNS1, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='CNS: Neuro vs Non-Neuro', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 2259
# Only Neuro: 310
# Only Mus: 762
# Neither Neuro nor Mus: 632
# Dropping 99
# (1619, 9)
# Index(['Physical Health Days', 'Mental Health Days', 'Bed Days', 'Bio Sex',
#        'Disability', 'musculo', 'neither', 'both', 'neuro'],
#       dtype='object')
# musculo group: 348
# neither group: 152
# both group: 979
# neuro group: 140

# %%
# PNS1
# Days Statistics (all Add'l Circumstances)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_PNS1, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='PNS: Neuro vs Non-Neuro', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 2227
# Only Neuro: 248
# Only Mus: 794
# Neither Neuro nor Mus: 694
# Dropping 99
# (1619, 9)
# Index(['Physical Health Days', 'Mental Health Days', 'Bed Days', 'Bio Sex',
#        'Disability', 'musculo', 'neither', 'both', 'neuro'],
#       dtype='object')
# musculo group: 399
# neither group: 180
# both group: 928
# neuro group: 112

# %%
# CNS1
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_CNS1, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='CNS: Neuro vs Non-Neuro')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 2259
# Only Neuro: 310
# Only Mus: 762
# Neither Neuro nor Mus: 632
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Babesia', 'Ehrlichia/ Anaplasma',
#        'tick born coinfection', 'Mycoplasma', 'Rickettsia', 'musculo',
#        'neither', 'both', 'neuro'],
#       dtype='object')
# musculo group: 387
# neither group: 319
# both group: 1107
# neuro group: 169

# %%
# OWD
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_OWD, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='OWD: Neuro vs Non-Neuro')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1562
# Only Neuro: 632
# Only Mus: 963
# Neither Neuro nor Mus: 806
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Babesia', 'Ehrlichia/ Anaplasma',
#        'tick born coinfection', 'Mycoplasma', 'Rickettsia', 'musculo',
#        'neither', 'both', 'neuro'],
#       dtype='object')
# musculo group: 501
# neither group: 417
# both group: 732
# neuro group: 332

# %%
# PNS1
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_PNS1, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='PNS: Neuro vs Non-Neuro')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 2227
# Only Neuro: 248
# Only Mus: 794
# Neither Neuro nor Mus: 694
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Babesia', 'Ehrlichia/ Anaplasma',
#        'tick born coinfection', 'Mycoplasma', 'Rickettsia', 'musculo',
#        'neither', 'both', 'neuro'],
#       dtype='object')
# musculo group: 429
# neither group: 354
# both group: 1065
# neuro group: 134
