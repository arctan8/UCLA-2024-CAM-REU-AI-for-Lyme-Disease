# %%
# %run ../../import_src.py

import lymedata
from lymedata import *
import constants
from constants import *

import display_stats
from display_stats import *

# %%
# CNS1
# Days Statistics (all Add'l Circumstnaces)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_CNS1, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='CNS1: Neuro vs Musculo vs Both vs Neither', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 2259
# Only Neuro: 310
# Only Mus: 762
# Neither Neuro nor Mus: 632
# Dropping 99
# (1619, 9)
# Index(['Disability', 'Mental Health Days', 'Bio Sex', 'Bed Days',
#        'Physical Health Days', 'neither', 'musculo', 'neuro', 'both'],
#       dtype='object')
# neither group: 152
# musculo group: 348
# neuro group: 140
# both group: 979

# %%
# CNS2
# Days Statistics (all Add'l Circumstnaces)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_CNS2, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='CNS: Neuro vs Musculo vs Both vs Neither', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1862
# Only Neuro: 707
# Only Mus: 762
# Neither Neuro nor Mus: 632
# Dropping 99
# (1619, 9)
# Index(['Disability', 'Mental Health Days', 'Bio Sex', 'Bed Days',
#        'Physical Health Days', 'neither', 'musculo', 'neuro', 'both'],
#       dtype='object')
# neither group: 152
# musculo group: 348
# neuro group: 324
# both group: 795

# %%
# CNS3
# Days Statistics (all Add'l Circumstances)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_CNS3, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='CNS3: Neuro vs Musculo vs Both vs Neither', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1862
# Only Neuro: 707
# Only Mus: 528
# Neither Neuro nor Mus: 866
# Dropping 99
# (1619, 9)
# Index(['Disability', 'Mental Health Days', 'Bio Sex', 'Bed Days',
#        'Physical Health Days', 'neither', 'musculo', 'neuro', 'both'],
#       dtype='object')
# neither group: 264
# musculo group: 236
# neuro group: 324
# both group: 795

# %%
# CNS1
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_CNS1, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='CNS1: Neuro vs Musculo vs Both vs Neither')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 2259
# Only Neuro: 310
# Only Mus: 762
# Neither Neuro nor Mus: 632
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Mycoplasma', 'Rickettsia', 'tick born coinfection',
#        'Babesia', 'Ehrlichia/ Anaplasma', 'neither', 'musculo', 'neuro',
#        'both'],
#       dtype='object')
# neither group: 319
# musculo group: 387
# neuro group: 169
# both group: 1107

# %%
# CNS2
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_CNS2, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='CNS2: Neuro vs Musculo vs Both vs Neither')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1862
# Only Neuro: 707
# Only Mus: 762
# Neither Neuro nor Mus: 632
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Mycoplasma', 'Rickettsia', 'tick born coinfection',
#        'Babesia', 'Ehrlichia/ Anaplasma', 'neither', 'musculo', 'neuro',
#        'both'],
#       dtype='object')
# neither group: 319
# musculo group: 387
# neuro group: 374
# both group: 902

# %%
# CN3
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_CNS3, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='CNS3: Neuro vs Musculo vs Both vs Neither')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1862
# Only Neuro: 707
# Only Mus: 528
# Neither Neuro nor Mus: 866
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Mycoplasma', 'Rickettsia', 'tick born coinfection',
#        'Babesia', 'Ehrlichia/ Anaplasma', 'neither', 'musculo', 'neuro',
#        'both'],
#       dtype='object')
# neither group: 444
# musculo group: 262
# neuro group: 374
# both group: 902

# %%
# PNS1
# Days Statistics (all Add'l Circumstnaces)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_PNS1, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='PNS1: Neuro vs Musculo vs Both vs Neither', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 2227
# Only Neuro: 248
# Only Mus: 794
# Neither Neuro nor Mus: 694
# Dropping 99
# (1619, 9)
# Index(['Disability', 'Mental Health Days', 'Bio Sex', 'Bed Days',
#        'Physical Health Days', 'neither', 'musculo', 'neuro', 'both'],
#       dtype='object')
# neither group: 180
# musculo group: 399
# neuro group: 112
# both group: 928

# %%
# PNS2
# Days Statistics (all Add'l Circumstnaces)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_PNS2, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='PNS2: Neuro vs Musculo vs Both vs Neither', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1898
# Only Neuro: 577
# Only Mus: 794
# Neither Neuro nor Mus: 694
# Dropping 99
# (1619, 9)
# Index(['Disability', 'Mental Health Days', 'Bio Sex', 'Bed Days',
#        'Physical Health Days', 'neither', 'musculo', 'neuro', 'both'],
#       dtype='object')
# neither group: 180
# musculo group: 399
# neuro group: 246
# both group: 794

# %%
# PNS3
# Days Statistics (all Add'l Circumstnaces)
# -Bed days
# -Mental health days
# -Physical health days
# -Disability
# -Bio sex
data = LymeData({CHRONIC, NEURO, MUSCULO},{ADDL_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'Bio Sex','Bed Days',
       'Mental Health Days', 'Physical Health Days', 'Disability'}, defn=DEF_PNS3, drop_99=True)
print(data.df.shape)
print(data.df.columns)
display_stats(data, title='PNS3: Neuro vs Musculo vs Both vs Neither', xlabel='Relative Frequency of Response "1"', ylabel='Sick Days (Additional Circumstances)')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1898
# Only Neuro: 577
# Only Mus: 492
# Neither Neuro nor Mus: 996
# Dropping 99
# (1619, 9)
# Index(['Disability', 'Mental Health Days', 'Bio Sex', 'Bed Days',
#        'Physical Health Days', 'neither', 'musculo', 'neuro', 'both'],
#       dtype='object')
# neither group: 342
# musculo group: 237
# neuro group: 246
# both group: 794

# %%
# PNS1
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_PNS1, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='PNS1: Neuro vs Musculo vs Both vs Neither')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 2227
# Only Neuro: 248
# Only Mus: 794
# Neither Neuro nor Mus: 694
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Mycoplasma', 'Rickettsia', 'tick born coinfection',
#        'Babesia', 'Ehrlichia/ Anaplasma', 'neither', 'musculo', 'neuro',
#        'both'],
#       dtype='object')
# neither group: 354
# musculo group: 429
# neuro group: 134
# both group: 1065

# %%
# PNS2
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_PNS2, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='PNS2: Neuro vs Musculo vs Both vs Neither')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1898
# Only Neuro: 577
# Only Mus: 794
# Neither Neuro nor Mus: 694
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Mycoplasma', 'Rickettsia', 'tick born coinfection',
#        'Babesia', 'Ehrlichia/ Anaplasma', 'neither', 'musculo', 'neuro',
#        'both'],
#       dtype='object')
# neither group: 354
# musculo group: 429
# neuro group: 305
# both group: 894

# %%
# PNS3
# Coinfections Statistcs (all Diagnostic Circumstances)
# -Babesia
# -Bartonella
# -Erlichia
# -Mycoplasma
# -Rikettsia
# -Tick-borne coinfections

data = LymeData({CHRONIC, NEURO, MUSCULO},{DIAG_CIR},{NEURO, MUSCULO, BOTH, NEITHER}, individual_cols={'tick born coinfection',
       'Babesia', 'Bartonella', 'Ehrlichia/ Anaplasma', 'Mycoplasma',
       'Rickettsia'}, defn=DEF_PNS3, drop_99=True)
print(data.df.shape)
print(data.df.columns)

display_stats(data, xlabel='Relative Frequency of Response "1"', ylabel='Coinfections', title='PNS3: Neuro vs Musculo vs Both vs Neither')
# Out:
# /home/reu24lyme/alex/code_lib/src/lymedata.py:74: DtypeWarning: Columns (224,249,259,269,274,294,299,304,309,339,344,365,369,373,377,395,399,403,411,415,419,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Both Neuro and Mus: 1898
# Only Neuro: 577
# Only Mus: 492
# Neither Neuro nor Mus: 996
# Dropping 99
# (1982, 10)
# Index(['Bartonella', 'Mycoplasma', 'Rickettsia', 'tick born coinfection',
#        'Babesia', 'Ehrlichia/ Anaplasma', 'neither', 'musculo', 'neuro',
#        'both'],
#       dtype='object')
# neither group: 513
# musculo group: 270
# neuro group: 305
# both group: 894
